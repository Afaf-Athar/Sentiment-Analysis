# %%
import numpy as np
import pandas as pd

# %%
text = open('read.txt',encoding='utf-8').read()

print(text)
# Out:
# I @Loved Python! and i feel victimized as my current scenario doesn't favour my dreams. :/ But now I feel happy because i am saved of being victimized
# Sometimes I try to find a solution so that I don’t have to be sad. But with deep thinking I get to know without sadness the recipe of life is incomplete.
# To give a taste to the recipe, I need to put all the emotions in the plate of life.
# Sadness is a natural part of life as happiness is. As human I will have to taste every flavour of life whether I like it or not. And if anyone tries to escape from any flavour, he will not be rewarded with his favourite one happiness.
# If sadness would not be good, then why I go to watch emotional movies. These movies don’t give me any smile or laughter rather they make my eyes wet.
# I like it because I enjoy being the part of character’s sadness. It means I like being sad and wanna feel this emotion too. And so do you all.
# ...

# %%
#conversion to lower case
lower_case = text.lower()
print(lower_case)
# Out:
# i @loved python! and i feel victimized as my current scenario doesn't favour my dreams. :/ but now i feel happy because i am saved of being victimized
# sometimes i try to find a solution so that i don’t have to be sad. but with deep thinking i get to know without sadness the recipe of life is incomplete.
# to give a taste to the recipe, i need to put all the emotions in the plate of life.
# sadness is a natural part of life as happiness is. as human i will have to taste every flavour of life whether i like it or not. and if anyone tries to escape from any flavour, he will not be rewarded with his favourite one happiness.
# if sadness would not be good, then why i go to watch emotional movies. these movies don’t give me any smile or laughter rather they make my eyes wet.
# i like it because i enjoy being the part of character’s sadness. it means i like being sad and wanna feel this emotion too. and so do you all.
# ...

# %%
#Removing Punctuations
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
#str1:='abc'- Specifies the list of characters that need to be replced
#str2:='gef'- Specifies the list of characters with which the characters need to be replaced
#str3: Specifies character that needs to be deleted

#Cleaning of text
cleaned_text = lower_case.translate(str.maketrans('','',string.punctuation))
print(cleaned_text)
# Out:
# i loved python and i feel victimized as my current scenario doesnt favour my dreams  but now i feel happy because i am saved of being victimized
# sometimes i try to find a solution so that i don’t have to be sad but with deep thinking i get to know without sadness the recipe of life is incomplete
# to give a taste to the recipe i need to put all the emotions in the plate of life
# sadness is a natural part of life as happiness is as human i will have to taste every flavour of life whether i like it or not and if anyone tries to escape from any flavour he will not be rewarded with his favourite one happiness
# if sadness would not be good then why i go to watch emotional movies these movies don’t give me any smile or laughter rather they make my eyes wet
# i like it because i enjoy being the part of character’s sadness it means i like being sad and wanna feel this emotion too and so do you all
# ...

# %%
#tokenization
tokenized_words = cleaned_text.split()
print(tokenized_words)
# Out:
# ['i', 'loved', 'python', 'and', 'i', 'feel', 'victimized', 'as', 'my', 'current', 'scenario', 'doesnt', 'favour', 'my', 'dreams', 'but', 'now', 'i', 'feel', 'happy', 'because', 'i', 'am', 'saved', 'of', 'being', 'victimized', 'sometimes', 'i', 'try', 'to', 'find', 'a', 'solution', 'so', 'that', 'i', 'don’t', 'have', 'to', 'be', 'sad', 'but', 'with', 'deep', 'thinking', 'i', 'get', 'to', 'know', 'without', 'sadness', 'the', 'recipe', 'of', 'life', 'is', 'incomplete', 'to', 'give', 'a', 'taste', 'to', 'the', 'recipe', 'i', 'need', 'to', 'put', 'all', 'the', 'emotions', 'in', 'the', 'plate', 'of', 'life', 'sadness', 'is', 'a', 'natural', 'part', 'of', 'life', 'as', 'happiness', 'is', 'as', 'human', 'i', 'will', 'have', 'to', 'taste', 'every', 'flavour', 'of', 'life', 'whether', 'i', 'like', 'it', 'or', 'not', 'and', 'if', 'anyone', 'tries', 'to', 'escape', 'from', 'any', 'flavour', 'he', 'will', 'not', 'be', 'rewarded', 'with', 'his', 'favourite', 'one', 'happiness', 'if', 'sadness', 'w
# ...

# %%
#stoppers - words that add no meaning/emotions to the sentence are called stop words
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these",
              "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do",
              "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
              "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before",
              "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again",
              "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each",
              "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
              "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
final_words = []
for word in tokenized_words:
  if word not in stop_words:
    final_words.append(word)

final_words
# Out:
# ['loved',
#  'python',
#  'feel',
#  'victimized',
#  'current',
#  'scenario',
#  'doesnt',
#  'favour',
#  'dreams',
#  'feel',
#  'happy',
#  'saved',
#  'victimized',
#  'sometimes',
#  'try',
#  'find',
#  'solution',
#  'don’t',
#  'sad',
#  'deep',
#  'thinking',
#  'get',
#  'know',
#  'without',
#  'sadness',
#  'recipe',
#  'life',
#  'incomplete',
#  'give',
#  'taste',
#  'recipe',
#  'need',
#  'put',
#  'emotions',
#  'plate',
#  'life',
#  'sadness',
#  'natural',
#  'part',
#  'life',
#  'happiness',
#  'human',
#  'taste',
#  'every',
#  'flavour',
#  'life',
#  'whether',
#  'like',
#  'anyone',
#  'tries',
#  'escape',
#  'flavour',
#  'rewarded',
#  'favourite',
#  'one',
#  'happiness',
#  'sadness',
#  'would',
#  'good',
#  'go',
#  'watch',
#  'emotional',
#  'movies',
#  'movies',
#  'don’t',
#  'give',
#  'smile',
#  'laughter',
#  'rather',
#  'make',
#  'eyes',
#  'wet',
#  'like',
#  'enjoy',
#  'part',
#  'character’s',
#  'sadness',
#  'means',
# ...

# %%
# NLP Emotion Algorithm
# 1) Check if the word in the final word list is also present in emotion.txt
#  - open the emotion file
#  - Loop through each line and clear it
#  - Extract the word and emotion using split

# 2) If word is present -> Add the emotion to emotion_list
# 3) Finally count each emotion in the emotion list

# %%
#2
emotion_list = []
with open('emotions.txt','r') as file:
  for line in file:
    #print(line)
    clear_line = line.replace('\n','').replace("'",'').strip()
    #print(clear_line)
    word, emotion = clear_line.split(':')
    #print("Word :"+ word + " " + "Emotion :" + emotion)

    if word in final_words:
       emotion_list.append(emotion)

print(emotion_list)
# Out:
# [' cheated,', ' happy,', ' happy,', ' happy,', ' attached,', ' happy,', ' attracted,', ' obsessed,', ' alone,', ' free,', ' hated,', ' sad,', ' happy,', ' entitled,', ' sad,', ' happy,', ' loved,', ' hated,', ' entitled,']

# %%
from collections import Counter 
w = Counter(emotion_list)
print(w)
# Out:
# Counter({' happy,': 6, ' hated,': 2, ' sad,': 2, ' entitled,': 2, ' cheated,': 1, ' attached,': 1, ' attracted,': 1, ' obsessed,': 1, ' alone,': 1, ' free,': 1, ' loved,': 1})

# %%
import matplotlib.pyplot as plt

fig, axl = plt.subplots()
axl.bar(w.keys(),w.values())
fig.autofmt_xdate()
plt.savefig('Graph.png')
plt.show()
